# %% [markdown]
# # AURA Kaggle verified one-run VTO POC
# Attach an authorized private AURA dataset or clone an authorized repository into `/kaggle/working/aura`; never publish private inputs.

# %%
# Kaggle uses the same executable cells as AURA_VTO_FREE_COLAB.ipynb.
# It detects KAGGLE_KERNEL_RUN_TYPE and selects /kaggle/working/aura.
# Copy cells 2–5 unchanged after placing the authorized project there.
I_CONFIRM_PERSONAL_IMAGE=False
RUN_ONE_CONTROLLED_INFERENCE=False
